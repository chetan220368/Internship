# %%
import numpy as np
from bs4 import BeautifulSoup
import requests
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException,InvalidArgumentException,InvalidCookieDomainException

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = 'https://www.amazon.in/'
driver.get(url)

# %%
item = input("Enter an Item to search: ")
# Out:
# Enter an Item to search: laptop

# %%
search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys(item)
search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
prod_url = []
prod_url_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")

# %%
for u in prod_url_tag:
    try:
        prod_url.append(u.get_attribute("href"))
    
    except:
        prod_url.append('-')

# %%
import time 

try:
    num_page = driver.find_element_by_xpath('//*[@class="a-pagination"]/li[20]')
except NoSuchElementException:
    num_page = driver.find_element_by_class_name('a-last').click()

# %%
Brand = []
prod = []
rate = []
ratenum = []
price = []
ex = []
delv = []
avl = []
det = []

# %%
for i in prod_url:
    driver.get(i)
    time.sleep(5)
    try:
        brandtag = driver.find_element_by_xpath("//td[@class='a-size-base prodDetAttrValue']")
        Brand.append(brandtag.text)
    except:
        Brand.append('-')
    try:
        prodtag = driver.find_element_by_xpath("//span[@class='a-size-large product-title-word-break']")
        prod.append(prodtag.text)
    except:
        prod.append('-')
    try:
        ratetag = driver.find_element_by_xpath("//div[@id='averageCustomerReviews']//span[@class='a-icon-alt']")
        rate.append(ratetag.get_attribute("innerHTML"))
    except NoSuchElementException:
        rate.append('-')
    try:
        ratenumtag = driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        ratenum.append(ratenumtag.get_attribute("innerHTML"))
    except:
        ratenum.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//span[@id='priceblock_ourprice']")
        price.append(pricetag.text)
    except:
        price.append('-')
    
    try:
        extag = driver.find_element_by_xpath("//div[@class='a-accordion-row-a11y']//h5")
        ex.append(extag.text.replace('\n',' ').replace('   ',''))
    except:
        ex.append('-')
    
    try:
        delvtag = driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']//b")
        delv.append(delvtag.text)
    except:
        delv.append('-')
    try:
        avltag = driver.find_element_by_xpath("//div[@id='availability']//span")
        avl.append(avltag.text)
    except:
        avl.append('-')
    try:
        dettag = driver.find_element_by_xpath("//div[@id='feature-bullets']")
        det.append(dettag.text.replace('\nShow More','.').replace('\n',''))
    except:
        det.append('-')

# %%
Laptops = {'Brand Name':Brand,'Product Name':prod,'Price(₹)':price,'Rating':rate,'Number of Ratings':ratenum ,'Exchange':ex,'Expected Delivery':delv,'Availablitiy':avl,'Details':det,'Product URL':prod_url}

Laptops  = pd.DataFrame(Laptops)

# %%
Laptops
# Out:
#    Brand Name                                       Product Name  \
# 0          LG  LG Gram 16 Ultra-Light 11th Gen Core i5,8 GB R...
# 1          LG  LG Gram Ultra-Light 11th Gen Core i7,16 GB RAM...
# 2        Acer  Acer Aspire 3 AMD Athlon Silver 3050U Dual-cor...
# 3          HP  HP Chromebook 14-inch (35.56 cms) Thin & Light...
# 4        ASUS  ASUS VivoBook 14 (2020), 14-inch (35.56 cms) F...
# 5         RDP  RDP ThinBook 1010 - Intel Celeron Quad Core Pr...
# 6          HP  HP 15 AMD Athlon 15.6" (39.62cms) HD Laptop (S...
# 7      Lenovo  Lenovo V15 AMD 15.6-inch (39.6 cm) FHD Thin an...
# 8          HP  HP 15 Intel Pentium Gold 6405U Processor Entry...
# 9      Lenovo  Lenovo IdeaPad Slim 3 AMD Athlon Silver 3050U ...
# 10     Lenovo  Lenovo IdeaPad Slim 3 (2021) | AMD Ryzen 5 |14...
# 11     Lenovo  Lenovo IdeaPad Slim 5 11th Gen Intel Core i5 1...
# 12     Lenovo  Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...
# 13     Lenovo  Lenovo IdeaPad Slim 3 10th Gen Intel Core i3 1...
# 14         HP  HP 15 (2021) Thin & Light Ryzen 3-3250 Laptop,...
# 15     Lenovo  Lenovo IdeaPad Slim 3 AMD 3020e 15.6" (39.63cm...
# 16         HP  HP Pavilion (2021) Thin & Light 11th Gen Core ...
# 17         MI  Mi Notebook Ultra 3K Resolution Display Intel ...
# 18         HP  HP 15 (2021) Thin & Light Ryzen 3-3250 Laptop,...
# 19     Lenovo  Lenovo IdeaPad Slim 3 2021 11th Gen Intel Core...
# 20     Lenovo  Lenovo IdeaPad Slim 3 2021 11th Gen Intel Core...
# 21     Lenovo  Lenovo IdeaPad Slim 3 10th Gen Intel Core i3 1...
#
#         Price(₹)              Rating Number of Ratings  \
# 0     ₹99,492.00  4.5 out of 5 stars        83 ratings
# 1   ₹1,18,868.00  4.5 out of 5 stars        51 ratings
# 2     ₹28,578.00                   -                 -
# 3     ₹27,999.00  3.9 out of 5 stars       762 ratings
# 4     ₹31,990.00  3.9 out of 5 stars       154 ratings
# 5     ₹25,000.00  3.4 out of 5 stars       255 ratings
# 6              -  3.5 out of 5 stars       478 ratings
# 7     ₹30,999.00  3.4 out of 5 stars       152 ratings
# 8              -  3.4 out of 5 stars       840 ratings
# 9              -  3.3 out of 5 stars        74 ratings
# 10    ₹53,990.00  4.5 out of 5 stars       131 ratings
# 11    ₹66,690.00  3.9 out of 5 stars        17 ratings
# 12    ₹35,000.00  4.1 out of 5 stars       483 ratings
# 13    ₹39,990.00  4.0 out of 5 stars       277 ratings
# 14    ₹38,499.00  3.9 out of 5 stars     1,662 ratings
# 15             -  3.6 out of 5 stars       375 ratings
# 16             -  4.4 out of 5 stars     1,009 ratings
# 17    ₹76,999.00  4.3 out of 5 stars        94 ratings
# 18    ₹42,499.00  4.2 out of 5 stars     1,668 ratings
# 19    ₹37,995.00  3.3 out of 5 stars        17 ratings
# 20    ₹54,990.00  3.6 out of 5 stars         7 ratings
# 21    ₹37,350.00  4.0 out of 5 stars       457 ratings
#
#                              Exchange  Expected Delivery  \
# 0   With Exchange Up to 18,400.00 off        Sep 28 - 30
# 1   With Exchange Up to 18,400.00 off    Thursday, Oct 7
# 2   With Exchange Up to 18,400.00 off    Tuesday, Sep 28
# 3   With Exchange Up to 18,400.00 off     Sunday, Sep 26
# 4   With Exchange Up to 18,400.00 off     Sunday, Sep 26
# 5   With Exchange Up to 18,400.00 off     Sunday, Sep 26
# 6                                   -                  -
# 7   With Exchange Up to 18,400.00 off  Wednesday, Sep 29
# 8                                   -                  -
# 9                                   -                  -
# 10  With Exchange Up to 18,400.00 off        Oct 16 - 18
# 11  With Exchange Up to 18,400.00 off    Tuesday, Sep 28
# 12                                  -     Sep 30 - Oct 1
# 13  With Exchange Up to 18,400.00 off    Tuesday, Sep 28
# 14  With Exchange Up to 18,400.00 off        Oct 22 - 23
# 15                                  -                  -
# 16                                  -                  -
# 17  With Exchange Up to 18,400.00 off     Sunday, Sep 26
# 18  With Exchange Up to 18,400.00 off    Tuesday, Sep 28
# 19  With Exchange Up to 18,400.00 off     Sunday, Sep 26
# 20  With Exchange Up to 18,400.00 off    Tuesday, Sep 28
# 21  With Exchange Up to 18,400.00 off     Sunday, Sep 26
#
#                        Availablitiy  \
# 0   In stock on September 26, 2021.
# 1                         In stock.
# 2                         In stock.
# 3                         In stock.
# 4                         In stock.
# 5                         In stock.
# 6
# 7                         In stock.
# 8
# 9
# 10    In stock on October 14, 2021.
# 11                        In stock.
# 12            Only 2 left in stock.
# 13                        In stock.
# 14    In stock on October 20, 2021.
# 15
# 16
# 17                        In stock.
# 18                        In stock.
# 19                        In stock.
# 20                        In stock.
# 21                        In stock.
#
#                                               Details  \
# 0   About this itemProcessor & OS: Intel 11th Gen ...
# 1   About this itemProcessor & OS: Intel 11th Gen ...
# 2   About this itemLaptopsProcessor : AMD Athlon S...
# 3   About this itemGOOGLE ASSISTANT: Voice-Enabled...
# 4   About this itemProcessor: AMD Ryzen 3 3250U Pr...
# 5   About this itemIntel Celeron Quad Core Process...
# 6   About this itemProcessor: AMD Athlon Silver 30...
# 7   About this itemCommercial Grade Durable Laptop...
# 8   About this itemDesign & Battery: Thin and ligh...
# 9   About this itemProcessor: AMD Athlon Silver 30...
# 10  About this itemProcessor: 5th Gen AMD Ryzen 5 ...
# 11  About this itemProcessor: 11th Gen Intel Tiger...
# 12  About this itemProcessor: Intel Celeron N4020 ...
# 13  About this itemProcessor: 10th Gen Intel Core ...
# 14  About this itemProcessor: AMD Ryzen 3 3250U (2...
# 15  About this itemIn the box: Laptop, Power Adapt...
# 16  About this itemProcessor: 11th Gen Intel Core ...
# 17  About this itemProcessor: 11th Gen Intel Tiger...
# 18  About this itemProcessor: AMD Ryzen 3 3250U (2...
# 19  About this itemProcessor: 11th Gen Intel Core ...
# 20  About this itemProcessor: 11th Gen Intel Core ...
# 21  About this itemProcessor: 10th Gen Intel Core ...
#
#                                           Product URL
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/Acer-Aspire-Athlon-Dual-...
# 3   https://www.amazon.in/HP-Chromebook-14a-na0003...
# 4   https://www.amazon.in/ASUS-VivoBook-Integrated...
# 5   https://www.amazon.in/RDP-ThinBook-1010-Celero...
# 6   https://www.amazon.in/HP-Athlon-15-6-inch-Silv...
# 7   https://www.amazon.in/Lenovo-15-6-inch-Integra...
# 8   https://www.amazon.in/HP-Pentium-Processor-15-...
# 9   https://www.amazon.in/Lenovo-Integrated-Graphi...
# 10  https://www.amazon.in/gp/slredirect/picassoRed...
# 11  https://www.amazon.in/gp/slredirect/picassoRed...
# 12  https://www.amazon.in/Lenovo-IdeaPad-39-62cms-...
# 13  https://www.amazon.in/Lenovo-Graphics-Warranty...
# 14  https://www.amazon.in/HP-3-3250-Laptop-Windows...
# 15  https://www.amazon.in/Lenovo-Integrated-Graphi...
# 16  https://www.amazon.in/HP-Pavilion-Graphics-Key...
# 17  https://www.amazon.in/Notebook-Resolution-i7-1...
# 18  https://www.amazon.in/HP-3-3250-Laptop-Windows...
# 19  https://www.amazon.in/Lenovo-IdeaPad-39-62cm-W...
# 20  https://www.amazon.in/gp/slredirect/picassoRed...
# 21  https://www.amazon.in/gp/slredirect/picassoRed...

# %%
Laptops.to_csv('Amazonscrape.csv') # Saving as .csv file

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
import urllib.request

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = 'https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.send_keys("fruits")       
search_button = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')    
search_button.click()

# %%
#Scroll to the end of the page
for i in range(500):
    driver.execute_script("window.scrollBy(0,15000)")

# %%
#Locate the images to be scraped from the current page 
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# 90

# %%
for i in range(len(img_urls)):
    if i >= 100:
        break
    response= requests.get(img_urls[i])

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = 'https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.send_keys("cars")       
search_button = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')    
search_button.click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# 43

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url='https://images.google.com'
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')    
search_bar.send_keys("Machine Learning")       
search_button = driver.find_element_by_xpath('//button[@class="Tg7LZd"]')    
search_button.click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

# %%
img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# 43

# %%
Google_images=pd.DataFrame({})
Google_images["100_Img_Fruits"]=img_urls[0:100]
Google_images["100_Img_Cars"]=img_urls[0:100]
Google_images["100_Img_ML"]=img_urls[0:100]
Google_images
# Out:
#                                        100_Img_Fruits  \
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 10  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 11  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 12  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 13  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 14  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 15  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 16  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 17  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 18  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 19  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 20  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 21  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 22  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 23  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 24  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 25  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 26  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 27  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 28  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 29  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 30  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 31  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 32  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 33  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 34  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 35  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 36  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 37  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 38  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 39  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 40  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 41  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 42  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                          100_Img_Cars  \
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 10  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 11  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 12  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 13  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 14  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 15  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 16  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 17  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 18  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 19  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 20  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 21  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 22  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 23  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 24  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 25  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 26  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 27  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 28  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 29  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 30  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 31  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 32  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 33  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 34  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 35  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 36  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 37  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 38  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 39  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 40  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 41  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 42  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                            100_Img_ML
# 0   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 5   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 6   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 7   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 8   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 9   https://encrypted-tbn0.gstatic.com/images?q=tb...
# 10  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 11  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 12  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 13  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 14  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 15  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 16  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 17  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 18  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 19  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 20  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 21  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 22  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 23  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 24  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 25  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 26  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 27  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 28  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 29  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 30  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 31  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 32  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 33  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 34  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 35  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 36  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 37  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 38  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 39  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 40  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 41  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 42  https://encrypted-tbn0.gstatic.com/images?q=tb...

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
url =  'https://www.flipkart.com/'
driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
item = input("Enter a smartphone name to search:")
# Out:
# Enter a smartphone name to search:samsung galaxy s20+

# %%
search = driver.find_element_by_xpath('/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search.send_keys(item)
searchbtn = driver.find_element_by_class_name('L0Z3Pu')
searchbtn.click()

# %%
produrl = []

# %%
produrl_tag = driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for u in produrl_tag:
     produrl.append(u.get_attribute("href"))

sep = ' | '

# %%
Brand = []
prod = []
Colour = []
RAM = []
price = []
Storage = []
PrimCamera = []
SecCamera = []
DispSize = []
DispRes = []
Processor = []
ProcCores = []
BatteryCap = []

# %%
for i in produrl:
    driver.get(i)
    time.sleep(3)
    morebtn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    morebtn.click()
    time.sleep(5)
    try:
        brandtag = driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        Brand.append(brandtag.text)
    except:
        Brand.append('-')
    try:
        prodtag = driver.find_element_by_xpath("//span[@class='B_NuCI']")
        prod.append(prodtag.text)
    except:
        prod.append('-')
    try:
        Colourtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li")
        Colour.append(Colourtag.text)
    except NoSuchElementException:
        Colour.append('-')
    try:
        RAMtag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[2]/td[2]/ul/li")
        RAM.append(RAMtag.text)
    except:
        RAM.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(pricetag.text)
    except:
        price.append('-')
    
    try:
        Storagetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][4]/table/tbody/tr[1]/td[2]/ul/li")
        Storage.append(Storagetag.text)
    except:
        Storage.append('-')
    try:
        PrimCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
        PrimCamera.append(PrimCameratag.text.split(sep, 1)[0])
    except:
        PrimCamera.append('-')
    
    try:
        SecCameratag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[3]")
        SecCamera.append(SecCameratag.text.split(sep, 1)[1])
    except:
        SecCamera.append('-')
    
    try:
        DispSizetag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][2]/table/tbody/tr[1]/td[2]/ul/li")
        DispSize.append(DispSizetag.text)
    except:
        DispSize.append('-')
    try:
        DispRestag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][2]/table/tbody/tr[2]/td[2]/ul/li")
        DispRes.append(DispRestag.text)
    except:
        DispRes.append('-')
    
    try:
        Processor_tag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][3]/table/tbody/tr[2]/td[2]/ul/li")
        Processor.append(Processor_tag.text)
    except:
        Processor.append('-')
        
        
    try:
        ProcCores_tag = driver.find_element_by_xpath("//div[@class='_3k-BhJ'][3]/table/tbody/tr[3]/td[2]/ul/li")
        ProcCores.append(ProcCores_tag.text)
    except:
        ProcCores.append('-')    
     
                    
    try:
        BatteryCap_tag = driver.find_element_by_xpath("//div[@class='_2418kt']/ul/li[4]")
        BatteryCap.append(BatteryCap_tag.text)
    except:
        BatteryCap.append('-')

# %%
Smartphone = {'Brand Name':Brand,'Smartphone Name':prod,'Price(₹)':price,'Colour':Colour,'RAM':RAM ,'Storage(ROM)':Storage,'Primary Camera':PrimCamera,'Secondary Camera':SecCamera,'Display Size':DispSize,'Display Resolution':DispRes,'Processor':Processor,'Processor Cores':ProcCores,'Battery Capacity':BatteryCap,'Product URL':produrl}

Smartphonedf  = pd.DataFrame(Smartphone)

# %%
Smartphonedf
# Out:
#          Brand Name                                    Smartphone Name  \
# 0   SAMSUNG Mobiles  SAMSUNG Galaxy S20 (Cloud Pink, 128 GB)  (8 GB...
# 1   SAMSUNG Mobiles  SAMSUNG Galaxy S20 (Cosmic Gray, 128 GB)  (8 G...
# 2   SAMSUNG Mobiles  SAMSUNG Galaxy S20 (Cloud Blue, 128 GB)  (8 GB...
# 3   SAMSUNG Mobiles  SAMSUNG Galaxy S20 FE (Cloud White, 128 GB)  (...
# 4   SAMSUNG Mobiles  SAMSUNG Galaxy S20 FE (Cloud Lavender, 128 GB)...
# 5   SAMSUNG Mobiles  SAMSUNG Galaxy S20 FE (Cloud Navy, 128 GB)  (8...
# 6   SAMSUNG Mobiles  SAMSUNG Galaxy S10 (Prism White, 512 GB)  (8 G...
# 7   SAMSUNG Mobiles  SAMSUNG Galaxy S20 Ultra (Cosmic Gray, 128 GB)...
# 8   SAMSUNG Mobiles  SAMSUNG Galaxy A30s (Prism Crush Black, 128 GB...
# 9   SAMSUNG Mobiles  SAMSUNG Galaxy S6 Edge (Black Sapphire, 32 GB)...
# 10  SAMSUNG Mobiles     SAMSUNG Galaxy A20s (Black, 64 GB)  (4 GB RAM)
# 11  SAMSUNG Mobiles  SAMSUNG Galaxy S10 Plus (Ceramic Black, 512 GB...
# 12  SAMSUNG Mobiles  SAMSUNG Galaxy S10 Plus (Ceramic White, 1 TB) ...
# 13  SAMSUNG Mobiles  SAMSUNG Galaxy A30s (Prism Crush Violet, 128 G...
# 14  SAMSUNG Mobiles     SAMSUNG Galaxy M30S (Blue, 128 GB)  (4 GB RAM)
# 15  SAMSUNG Mobiles      SAMSUNG Galaxy M30s (Blue, 64 GB)  (4 GB RAM)
# 16  SAMSUNG Mobiles      SAMSUNG Galaxy A20s (Blue, 32 GB)  (3 GB RAM)
# 17  SAMSUNG Mobiles  SAMSUNG Galaxy S20 FE (Cloud Red, 128 GB)  (8 ...
# 18  SAMSUNG Mobiles     SAMSUNG Galaxy A20s (Green, 32 GB)  (3 GB RAM)
# 19  SAMSUNG Mobiles     SAMSUNG Galaxy A20s (Black, 32 GB)  (3 GB RAM)
# 20  SAMSUNG Mobiles  SAMSUNG Galaxy A30s (Prism Crush White, 128 GB...
# 21  SAMSUNG Mobiles     SAMSUNG Galaxy A20s (Green, 64 GB)  (4 GB RAM)
# 22  SAMSUNG Mobiles  SAMSUNG Galaxy S10 (Prism Black, 128 GB)  (8 G...
# 23  SAMSUNG Mobiles      SAMSUNG Galaxy A20s (Blue, 64 GB)  (4 GB RAM)
#
#      Price(₹)              Colour                   RAM        Storage(ROM)  \
# 0     ₹74,000          Cloud Pink                  8 GB              128 GB
# 1     ₹52,905         Cosmic Gray                  8 GB              128 GB
# 2     ₹49,980          Cloud Blue                  8 GB              128 GB
# 3     ₹49,999         Cloud White                  8 GB              128 GB
# 4     ₹49,999      Cloud Lavender                  8 GB              128 GB
# 5     ₹49,999          Cloud Navy                  8 GB              128 GB
# 6     ₹92,000         Prism White                  8 GB              512 GB
# 7   ₹1,03,000         Cosmic Gray                 12 GB              128 GB
# 8     ₹18,199   Prism Crush Black                  4 GB              128 GB
# 9     ₹37,299                   -  0 0 Octa Core 2.1GHz  Android Lollipop 5
# 10    ₹14,900               Black                  4 GB               64 GB
# 11    ₹91,900       Ceramic Black                  8 GB              512 GB
# 12  ₹1,17,990       Ceramic White                 12 GB                1 TB
# 13    ₹19,900  Prism Crush Violet                  4 GB              128 GB
# 14    ₹13,990                Blue                  4 GB              128 GB
# 15    ₹14,090                Blue                  4 GB               64 GB
# 16    ₹11,599                Blue                  3 GB               32 GB
# 17    ₹49,999           Cloud Red                  8 GB              128 GB
# 18    ₹11,599               Green                  3 GB               32 GB
# 19    ₹11,599               Black                  3 GB               32 GB
# 20    ₹19,900   Prism Crush White                  4 GB              128 GB
# 21    ₹13,695               Green                  4 GB               64 GB
# 22    ₹39,999         Prism Black                  8 GB              128 GB
# 23    ₹13,695                Blue                  4 GB               64 GB
#
#                                Primary Camera              Secondary Camera  \
# 0                          64MP + 12MP + 12MP             10MP Front Camera
# 1                          64MP + 12MP + 12MP             10MP Front Camera
# 2                          64MP + 12MP + 12MP             10MP Front Camera
# 3               12MP + 12MP + 8MP Rear Camera             32MP Front Camera
# 4               12MP + 12MP + 8MP Rear Camera             32MP Front Camera
# 5               12MP + 12MP + 8MP Rear Camera             32MP Front Camera
# 6                                 16MP + 12MP             10MP Front Camera
# 7   108 MP + 48 MP + 12 MP + VGA Depth Camera             40MP Front Camera
# 8                            25MP + 5MP + 8MP             16MP Front Camera
# 9                            16MP Rear Camera              5MP Front Camera
# 10                           13MP + 8MP + 5MP              8MP Front Camera
# 11                                16MP + 12MP  10MP + 8MP Dual Front Camera
# 12                                16MP + 12MP  10MP + 8MP Dual Front Camera
# 13                           25MP + 5MP + 8MP             16MP Front Camera
# 14                                 48MP + 8MP             16MP Front Camera
# 15                           48MP Rear Camera             16MP Front Camera
# 16                           13MP + 8MP + 5MP              8MP Front Camera
# 17              12MP + 12MP + 8MP Rear Camera             32MP Front Camera
# 18                           13MP + 8MP + 5MP              8MP Front Camera
# 19                           13MP + 8MP + 5MP              8MP Front Camera
# 20                           25MP + 5MP + 8MP             16MP Front Camera
# 21                           13MP + 8MP + 5MP              8MP Front Camera
# 22                                16MP + 12MP             10MP Front Camera
# 23                           13MP + 8MP + 5MP              8MP Front Camera
#
#                                          Display Size  \
# 0                                 15.75 cm (6.2 inch)
# 1                                 15.75 cm (6.2 inch)
# 2                                 15.75 cm (6.2 inch)
# 3                                 16.51 cm (6.5 inch)
# 4                                 16.51 cm (6.5 inch)
# 5                                 16.51 cm (6.5 inch)
# 6                                 15.49 cm (6.1 inch)
# 7                                 17.53 cm (6.9 inch)
# 8                                 16.26 cm (6.4 inch)
# 9   Stereo headset, Travel Adaptor, Data Cable, Ha...
# 10                                16.51 cm (6.5 inch)
# 11                                16.26 cm (6.4 inch)
# 12                                16.26 cm (6.4 inch)
# 13                                16.26 cm (6.4 inch)
# 14                                16.26 cm (6.4 inch)
# 15                                16.26 cm (6.4 inch)
# 16                                16.51 cm (6.5 inch)
# 17                                16.51 cm (6.5 inch)
# 18                                16.51 cm (6.5 inch)
# 19                                16.51 cm (6.5 inch)
# 20                                16.26 cm (6.4 inch)
# 21                                16.51 cm (6.5 inch)
# 22                                15.49 cm (6.1 inch)
# 23                                16.51 cm (6.5 inch)
#
#                  Display Resolution            Processor Processor Cores  \
# 0                3200 x 1440 Pixels           Exynos 990       Octa Core
# 1                3200 x 1440 Pixels           Exynos 990       Octa Core
# 2                3200 x 1440 Pixels           Exynos 990       Octa Core
# 3                2400 x 1080 Pixels     Exynos Octa Core       Octa Core
# 4                2400 x 1080 Pixels     Exynos Octa Core       Octa Core
# 5                2400 x 1080 Pixels     Exynos Octa Core       Octa Core
# 6                 3040 x 1440 pixel        Exynos 9 9820       Octa Core
# 7                3200 x 1440 Pixels           Exynos 990       Octa Core
# 8                1920 x 1080 Pixels          Exynos 7904       Octa Core
# 9   SM-G925IZKAINS / SM-G925IZKAINU   2560 X 1440 Pixels         Quad HD
# 10                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
# 11                3040 x 1440 pixel        Exynos 9 9820       Octa Core
# 12                3040 x 1440 pixel        Exynos 9 9820       Octa Core
# 13               1920 x 1080 Pixels          Exynos 7904       Octa Core
# 14               2340 x 1080$$pixel            Octa Core         2.3 GHz
# 15              2340 x 1080$$Pixels          Exynos 9611       Octa Core
# 16                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
# 17               2400 x 1080 Pixels     Exynos Octa Core       Octa Core
# 18                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
# 19                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
# 20               1920 x 1080 Pixels          Exynos 7904       Octa Core
# 21                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
# 22                3040 x 1440 pixel        Exynos 9 9820       Octa Core
# 23                720 x 1520 Pixels  Qualcomm SDM450-B01       Octa Core
#
#                 Battery Capacity  \
# 0   4000 mAh Lithium-ion Battery
# 1   4000 mAh Lithium-ion Battery
# 2   4000 mAh Lithium-ion Battery
# 3   4500 mAh Lithium Ion Battery
# 4   4500 mAh Lithium Ion Battery
# 5   4500 mAh Lithium Ion Battery
# 6   3400 mAh Lithium-ion Battery
# 7   5000 mAh Lithium-ion Battery
# 8        4000 mAh Li-ion Battery
# 9               2600 mAh Battery
# 10  4000 mAh Lithium Ion Battery
# 11  4100 mAh Lithium-ion Battery
# 12  4100 mAh Lithium-ion Battery
# 13       4000 mAh Li-ion Battery
# 14              6000 mAh Battery
# 15              6000 mAh Battery
# 16  4000 mAh Lithium Ion Battery
# 17  4500 mAh Lithium Ion Battery
# 18  4000 mAh Lithium Ion Battery
# 19  4000 mAh Lithium Ion Battery
# 20       4000 mAh Li-ion Battery
# 21  4000 mAh Lithium Ion Battery
# 22  3400 mAh Lithium-ion Battery
# 23  4000 mAh Lithium Ion Battery
#
#                                           Product URL
# 0   https://www.flipkart.com/samsung-galaxy-s20-cl...
# 1   https://www.flipkart.com/samsung-galaxy-s20-co...
# 2   https://www.flipkart.com/samsung-galaxy-s20-cl...
# 3   https://www.flipkart.com/samsung-galaxy-s20-fe...
# 4   https://www.flipkart.com/samsung-galaxy-s20-fe...
# 5   https://www.flipkart.com/samsung-galaxy-s20-fe...
# 6   https://www.flipkart.com/samsung-galaxy-s10-pr...
# 7   https://www.flipkart.com/samsung-galaxy-s20-ul...
# 8   https://www.flipkart.com/samsung-galaxy-a30s-p...
# 9   https://www.flipkart.com/samsung-galaxy-s6-edg...
# 10  https://www.flipkart.com/samsung-galaxy-a20s-b...
# 11  https://www.flipkart.com/samsung-galaxy-s10-pl...
# 12  https://www.flipkart.com/samsung-galaxy-s10-pl...
# 13  https://www.flipkart.com/samsung-galaxy-a30s-p...
# 14  https://www.flipkart.com/samsung-galaxy-m30s-b...
# 15  https://www.flipkart.com/samsung-galaxy-m30s-b...
# 16  https://www.flipkart.com/samsung-galaxy-a20s-b...
# 17  https://www.flipkart.com/samsung-galaxy-s20-fe...
# 18  https://www.flipkart.com/samsung-galaxy-a20s-g...
# 19  https://www.flipkart.com/samsung-galaxy-a20s-b...
# 20  https://www.flipkart.com/samsung-galaxy-a30s-p...
# 21  https://www.flipkart.com/samsung-galaxy-a20s-g...
# 22  https://www.flipkart.com/samsung-galaxy-s10-pr...
# 23  https://www.flipkart.com/samsung-galaxy-a20s-b...

# %%
Smartphonedf.to_csv('FlipkartSmartphonescrape.csv') # Saving as .csv file

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
url =  'https://www.google.co.in/maps?hl=en&authuser=0'
driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
item = input("Enter a location name to search:")
# Out:
# Enter a location name to search:Bengaluru

# %%
import re

# %%
url = 'https://www.google.com/maps/search/{}'.format(item)

driver.get(url)
r = re.compile(r'center=(-?\d+\.\d+)%2C(-?\d+\.\d+)')
lat_long = r.findall(driver.page_source)


print(lat_long)

driver.quit()
# Out:
# [('12.9539974', '77.6309395'), ('12.9539974', '77.6309395')]

# %%
coordinates=lat_long[0:1]
coordinates
# Out:
# [('12.9539974', '77.6309395')]

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
url='https://trak.in/'
driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
fd = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(fd)

# %%
date=[]
startup=[]
industry=[]
subVertical=[]
location=[]
investor=[]
investment=[]
amount=[]

# %%
for i in range(48,51):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()

    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        date.append(d.text)

    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        startup.append(n.text)
    
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        industry.append(n.text)
    
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        subVertical.append(s.text)

    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        location.append(l.text)
    
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        investor.append(n.text)
    
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        investment.append(n.text)
    
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        amount.append(a.text)

# %%
import pandas as pd
df=pd.DataFrame({})
df['date']=date
df['startup']=startup 
df['industry']=industry
df['subVertical']=subVertical
df['location']=location
df['investor']=investor
df['investment']=investment
df['amount']=amount

# %%
df
# Out:
#           date                    startup  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  03/08/2020                 CrowdPouch
# 21  04/08/2020                 DrinkPrime
# 22  08/09/2020                     Byju’s
# 23  12/09/2020                  mCaffeine
# 24  09/09/2020                     Qshala
# 25  02/09/2020                      Winzo
# 26  09/09/2020                Hippo Video
# 27  07/09/2020                    Melorra
# 28  07/09/2020                        1mg
# 29  31/08/2020                      mfine
# 30  31/08/2020                       Apna
# 31  03/09/2020                    Railofy
# 32  08/09/2020            Cell Propulsion
#
#                                   industry  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 FinTech
# 21                      Water Purification
# 22                                 EduTech
# 23                           Personal Care
# 24                                 EduTech
# 25                           Online Gaming
# 26  Video Customer Experience(CX) Platform
# 27                              E-commerce
# 28                              E-commerce
# 29                              HealthTech
# 30                         Human Resources
# 31                          Transportation
# 32                              Automobile
#
#                                           subVertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                 Financial Services
# 21                                 Water Purification
# 22                                    Online Tutoring
# 23                                Skincare & Haircare
# 24                 Online Curiosity Platform for Kids
# 25                                      Online Gaming
# 26             Video Customer Experience(CX) Platform
# 27                               Online Jewelry Store
# 28                                    Online Pharmacy
# 29                      On-Demand Healthcare Services
# 30                               Recruitment Platform
# 31                       WL & RAC protection platform
# 32                        Electric Mobility Solutions
#
#                                       location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                   Bangalore
# 22                                   Bangalore
# 23                                      Mumbai
# 24                                   Bangalore
# 25                                   New Delhi
# 26  Newark, Delaware, United States of Amercia
# 27                                   Bangalore
# 28                                     Gurgaon
# 29                                   Bangalore
# 30                                   Bangalore
# 31                                      Mumbai
# 32                                   Bangalore
#
#                                              investor              investment  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20                         Elina Investments Pvt. Ltd                   Angel
# 21                        Sequoia Surge, ON Mauritius            Pre-Series A
# 22  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 23  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 24                                 Rainmatter Capital                   Angel
# 25  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 26  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 27                         Shadow Holdings, Lightbox.          Debt Financing
# 28         Gaja Capital, Tata Capital, Partners Group             In Progress
# 29                                   Caretech Pte Inc                Series B
# 30         Lightspeed India and Sequoia Capital India                Series A
# 31                                  Chiratae Ventures                    Seed
# 32                         growX Ventures and Micelio            pre-Series A
#
#              amount
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20               NA
# 21        2,880,000
# 22      500,000,000
# 23        3,000,000
# 24          370,000
# 25       15,500,000
# 26        4,500,000
# 27   upto 8,900,000
# 28      100,000,000
# 29        5,400,000
# 30        8,000,000
# 31          950,000
# 32               NA

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#loading the drivers,URL & maximizing the window-
driver=webdriver.Chrome('Chromedriver.exe')
driver.get('https://www.digit.in/')
driver.maximize_window()
driver.implicitly_wait(5)

# %%
btn = driver.find_element_by_xpath("//div[@class='listing_container']/ul/li[9]/a").get_attribute('href')
driver.get(btn)

# %%
html = driver.page_source

#reading tables using pandas-
df = pd.read_html(html)

#Scrapping specification_tables-
import numpy as np
num = np.arange(1,11)
laptop= []
for i in num:
    df1 = df[1].drop('SPECIFICATION.1', axis = 1)
    df2 = df1.drop('SPECIFICATION', axis = 1)
    ds = df2.transpose()    
    laptop.append(ds)

# %%
LAPTOP = pd.concat(laptop,ignore_index=True,join="inner")
LAPTOP['Product_Name']=df[0]['Product Name']
LAPTOP['Seller']=df[0]['Seller']
LAPTOP['Price']=df[0]['Price']

# %%
LAPTOP = LAPTOP.rename(columns={0 : "OS", 1: "Display",2: "Processor",3: "Memory",4: "Weight",5: "Dimension",6: "Graphics Processor"})
LAPTOP
# Out:
#                 OS              Display  \
# 0  Windows 10 Home  17.3" (1920 x 1080)
# 1  Windows 10 Home  17.3" (1920 x 1080)
# 2  Windows 10 Home  17.3" (1920 x 1080)
# 3  Windows 10 Home  17.3" (1920 x 1080)
# 4  Windows 10 Home  17.3" (1920 x 1080)
# 5  Windows 10 Home  17.3" (1920 x 1080)
# 6  Windows 10 Home  17.3" (1920 x 1080)
# 7  Windows 10 Home  17.3" (1920 x 1080)
# 8  Windows 10 Home  17.3" (1920 x 1080)
# 9  Windows 10 Home  17.3" (1920 x 1080)
#
#                                           Processor                 Memory  \
# 0  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 1  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 2  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 3  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 4  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 5  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 6  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 7  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 8  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
# 9  10th Generation Intel® Core™ i7-10700 | 2.90 GHz  1 TB SSD/16 GBGB DDR4
#
#   Weight               Dimension       Graphics Processor  \
# 0    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 1    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 2    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 3    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 4    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 5    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 6    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 7    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 8    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
# 9    4.1  27.65 x 402.6 x 319.14  Intel® UHD Graphics 630
#
#                Product_Name  Seller      Price
# 0     Alienware Area 51M R2     NaN        NaN
# 1          Alienware m15 R3     NaN  ₹ 341,990
# 2    ASUS ROG Strix Scar 15     NaN        NaN
# 3     Asus ROG Zephyrus G14  Amazon  ₹ 164,990
# 4          Lenovo Legion 5i  Amazon   ₹ 76,988
# 5  ASUS ROG ZEPHYRUS DUO 15  Amazon  ₹ 185,000
# 6      Acer Aspire 7 gaming  Amazon   ₹ 64,370
# 7                       NaN     NaN        NaN
# 8                       NaN     NaN        NaN
# 9                       NaN     NaN        NaN

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.forbes.com/billionaires/"
driver.get(url)

# %%
#Scraping Rank
rank = []
Rank = driver.find_elements_by_xpath("//div[@class='rank']")
for i in Rank:
    rank.append(i.text)

# %%
#Similarly for Name.net_worth,country and source

Name=[]
net_worth=[]
country=[]
source=[]
age=[]
industry=[]

# %%
name=driver.find_elements_by_xpath("//div[@class='personName']")
for i in name:
    Name.append(i.text)
    
Net_worth=driver.find_elements_by_xpath("//div[@class='netWorth']")
for i in Net_worth:
    net_worth.append(i.text)

Country=driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
for i in Country:
    country.append(i.text)
    
Source=driver.find_elements_by_xpath("//div[@class='source']")
for i in Source:
    source.append(i.text)

# %%
#Scraping For Age
Age=driver.find_elements_by_xpath("//div[@class='age']")
for i in Age:
    age.append(i.text)

# %%
#Scraping for Industry
Industry=driver.find_elements_by_xpath("//div[@class='category']")
for i in Industry:
    industry.append(i.text)

# %%
df=pd.DataFrame({})
df['Rank']=rank
df['Name']=Name
df['Age']=age
df['Net Worth']=net_worth
df['Country']=country
df['Source']=source
df['Industry']=industry

# %%
df
# Out:
#      Rank                      Name Age Net Worth        Country  \
# 0      1.                Jeff Bezos  57    $177 B  United States
# 1      2.                 Elon Musk  49    $151 B  United States
# 2      3.  Bernard Arnault & family  72    $150 B         France
# 3      4.                Bill Gates  65    $124 B  United States
# 4      5.           Mark Zuckerberg  36     $97 B  United States
# ..    ...                       ...  ..       ...            ...
# 195  195.           Harry Triguboff  88   $11.2 B      Australia
# 196  197.     Leonid Fedun & family  65   $11.1 B         Russia
# 197  197.                 Eyal Ofer  70   $11.1 B         Israel
# 198  197.              Evan Spiegel  30   $11.1 B  United States
# 199  200.     Luis Carlos Sarmiento  88     $11 B       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
url = input('Enter Youtube video URL:')
# Out:
# Enter Youtube video URL:https://www.youtube.com/watch?v=k2P_pHQDlp0&t=13s&ab_channel=KrishNaik

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.get(url)

# %%
i=0
while(i<100):
    driver.execute_script("window.scrollBy(0,500)") # scroll down to get more comments
    i+=1
while(i<402):
    driver.execute_script("window.scrollBy(0,5000)") # scroll down to get more comments
    i+=1

# %%
cmt = []
upvt = []
cmttime = []

# %%
cmt_tag = driver.find_elements_by_xpath("//*[@id='content-text']")
for i in cmt_tag:
    cmt.append(i.text.replace("\n",''))

upvt_tag = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")
for j in upvt_tag:
    try: 
        upvt.append(j.text)
    except:
        upvt.append('-')
cmttime_tag = driver.find_elements_by_xpath("//*[@id='header-author']/yt-formatted-string/a")
for k in cmttime_tag:
    try: 
        cmttime.append(k.text)
    except:
        cmttime.append('-')

# %%
len(upvt)
# Out:
# 20

# %%
len(cmt)
# Out:
# 20

# %%
len(cmttime)
# Out:
# 20

# %%
for i in range(0,len(upvt)):
    if upvt[i] == '': 
        upvt[i] = '-' # replacing empty string with '-'

# %%
Youtube = {'Comment':cmt,'Commented':cmttime,'Number of upvotes':upvt}

# %%
YoutubeDF = pd.DataFrame(Youtube)
YoutubeDF
# Out:
#                                               Comment               Commented  \
# 0   Please do subscribe my vlogging channel for mo...            5 months ago
# 1   I don't know why all the youtubers explains st...              1 year ago
# 2   When I'm going to get a job on AI, I'm gonna d...              1 year ago
# 3   Finally a good explanation that doesn't hide c...              1 year ago
# 4   I would like to thank all the YouTube teachers...              1 year ago
# 5   currently watching as the quarantine period is...              1 year ago
# 6   Thank you very much for this video! Please not...            9 months ago
# 7   After long period of confusion I got to know t...  11 months ago (edited)
# 8   Correct. I've soon got my masters in IT engine...              1 year ago
# 9   Thanks Krish! I was looking for a video that c...              1 year ago
# 10  Amazing that you can break down these complica...              1 year ago
# 11  Reinforcement learning is giving confidence fr...              1 year ago
# 12  Today in this video I just came to understand ...            7 months ago
# 13  Thank you Krish for explaining AI, ML, DL, & D...              1 year ago
# 14  Damn  9 min lecture = to my whole semester cla...              1 year ago
# 15  Thank you Krish for this amazing tutorial. You...              1 year ago
# 16  Amazing content and a great way of teaching. S...              1 year ago
# 17  This video is really informative. This gives a...           11 months ago
# 18  Thank you so much great work I have binged you...            7 months ago
# 19  Thank you for providing this information!!  It...              1 year ago
#
#    Number of upvotes
# 0                 34
# 1               1.3K
# 2                463
# 3                368
# 4                 13
# 5                 71
# 6                  7
# 7                  4
# 8                 64
# 9                  5
# 10                 8
# 11                14
# 12                 1
# 13                 1
# 14                12
# 15                 2
# 16                28
# 17                 1
# 18                 1
# 19                 1

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver = webdriver.Chrome("chromedriver.exe")
url =  'https://www.hostelworld.com/'
driver.get(url)

# %%
srchbar = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/input')
srchbar.click() #clicking on searchbar

# %%
item = 'London, England'
srchbar = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/div/input')
srchbar.send_keys(item) #entering search keyword "London,England"

# %%
suggbtn = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div/span')
suggbtn.click() #clicking on first suggestion "London England"

# %%
gobtn =  driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[5]/button')
gobtn.click() #clicking on Let's go button

# %%
name = []
dist = []
rate = []
rev = []
ovrrev = []
pvt = []
dor = []
fac = []
desc = []
url = []

# %%
desc = []

# %%
url_tag = driver.find_elements_by_xpath("//a[@class='view-button']")
for u in url_tag:
    url.append(u.get_attribute("href"))

# %%
import time 


i=0

while(i<2):
    nextbtn = driver.find_element_by_xpath("//div[@class='pagination pagination']")
    nextbtn.click()
    time.sleep(3)
    url_tag = driver.find_elements_by_xpath("//a[@class='view-button']")
    for u in url_tag:
        url.append(u.get_attribute("href"))
    
    name_tag= driver.find_elements_by_xpath("//h2[@class='title title-6']//a")
    for n in name_tag:
        name.append(n.text)
    dist_tag= driver.find_elements_by_xpath("//a[@class='show-on-map']/span[1]")
    for d in dist_tag:
        dist.append(d.text)
    rate_tag= driver.find_elements_by_xpath("//div[@class='rating rating-summary-container big']/div[1]")
    for r in rate_tag:
        rate.append(r.text.replace('\n0 Total Reviews',''))
    rev_tag= driver.find_elements_by_xpath("//div[@class='reviews']")
    for re in rev_tag:
        rev.append(re.text)
    ovrrev_tag= driver.find_elements_by_xpath("//div[@class='rating rating-summary-container big']//span")
    for o in ovrrev_tag:
        ovrrev.append(o.text)
    pvt_tag= driver.find_elements_by_xpath("//a[@class='prices']/div[1]")
    for p in pvt_tag:
        pvt.append(p.text.replace("\n",''))
    dor_tag= driver.find_elements_by_xpath("//a[@class='prices']/div[2]")
    for d in dor_tag:
        dor.append(d.text.replace("\n",''))
    fac_tag= driver.find_elements_by_xpath("//div[@class='facilities-label facilities']")
    for f in fac_tag:
        fac.append(f.text.replace("\n",' + '))
    
    
    i=i+1

# %%
url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Abercorn-House/London/34216?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Best-London-Hostels/London/72053?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Le-Junction-Hostel-Pub-Garden/London/90013?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Seven-Sisters/London/91108?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Kensington-Holland-Park/London/93920?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Selina-Camden/London/310274?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kensal-Green-Backpackers/London/4483?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Backpackers/London/527?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Colliers-Hotel/London/308375?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Marble-Arch-Inn/London/13337?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/City-Hotel-Carlton/London/27551?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barry-House/London/287321?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/All-Star-Private-Studios/London/24709?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Britannia-Inn-Hotel/London/47955?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Fairway-Hotel/London/81121?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Green-Rooms/London/271479?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-House-Hotel/London/529?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Golders-Park-Hotel/London/305286?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Tony-s-House-Hotel/London/8503?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Town-Hotel/London/32376?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Belgravia-Hotel/London/306595?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Beaconsfield/London/11708?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Wembley-International-Hotel/London/26351?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Elmwood-Hotel/London/34338?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Victor-Hotel/London/76699?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Best-Western-Boltons-London-Kensington/London/266666?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Park-Hotel-Essex/London/10143?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Cranbrook-Hotel/London/10144?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Athans/London/16231?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Aron-Guest-House/London/64748?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Waterloo-Hostel/London/39493?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barmy-Badger-Backpackers/London/64746?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-The-City-Hostel-London/London/88047?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Prime-Backpackers-Angel/London/93902?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Camden-Inn-Hostel/London/596?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Green-Man-Paddington/London/21953?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/New-Cross-Inn-Hostel/London/15204?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Camden/London/505?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Shepherds-Bush/London/506?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Mapesbury-Hostel/London/19667?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hootananny-Hostel/London/24068?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix-Hostel/London/48221?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/247london-Hostel-and-Private-Rooms/London/64523?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Burlington-Residence/London/306383?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Clink261/London/516?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Russell-Square-Hostel/London/29412?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-View-Hostel/London/8069?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/The-Finnish-Church-in-London/London/80791?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Queen-Elizabeth-Chelsea/London/50443?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-Inn-Hostel/London/517?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Pickwick-Hall/London/7502?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Willesden-Hostel-London/London/18420?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Waterloo-Hostel/London/39493?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barmy-Badger-Backpackers/London/64746?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-The-City-Hostel-London/London/88047?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Prime-Backpackers-Angel/London/93902?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Camden-Inn-Hostel/London/596?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Green-Man-Paddington/London/21953?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/New-Cross-Inn-Hostel/London/15204?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Camden/London/505?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Shepherds-Bush/London/506?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Mapesbury-Hostel/London/19667?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hootananny-Hostel/London/24068?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Phoenix-Hostel/London/48221?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/247london-Hostel-and-Private-Rooms/London/64523?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Burlington-Residence/London/306383?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Clink261/London/516?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Russell-Square-Hostel/London/29412?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-View-Hostel/London/8069?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/The-Finnish-Church-in-London/London/80791?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Queen-Elizabeth-Chelsea/London/50443?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-Inn-Hostel/London/517?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Pickwick-Hall/London/7502?from=2021-10-01&to=2021-10-04&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Willesden-Hostel-London/London/18420?from=2021-10-01&to=2021-10-04&guests=2']

# %%
for u in url:
    driver.get(u)
    time.sleep(3)
    desc_tag = driver.find_element_by_xpath("//div[@class='collapsible']//div[2]")
    try:
        desc.append(desc_tag.text)
    except:
        desc.append('-')

# %%
del pvt[0:3] #removing unwanted values

# %%
len(pvt)
# Out:
# 93

# %%
Hostelworld = {'Hostel Name': name,'Distance From City Centre':dist,'Ratings':rate,'Total Reviews':rev,'Overall Reviews': ovrrev,"Privates From":pvt,'Dormitories From':dor,'Facilities':fac,'Property Description':desc}

# %% [markdown]
# #creating dataframe
# df = pd.DataFrame({'Hostel Name':name,
#                 'Distance from city centre':dist,
#                 'Overall Review':ovrrev,
#                 'Total Reviews':rev,
#                 'Facilities':fac,
#                 'Privates From Price':pvt,
#                 'Dorms From Price':dor,
#                 'Rating':rate,
#                 'Property Description':desc})
# df
